# %%
import pandas as pd
import joblib

# 1. 모델 경로 및 데이터 경로 설정
MODEL_PATH = "xgb_model.pkl"  # 모델 경로
CSV_PATH = "vpn환경_traffic캡처/session_ISCX_250511.csv"  # 입력 데이터 CSV 경로

# 2. 모델 로드
model = joblib.load(MODEL_PATH)

# 3. 입력 데이터 로드
df = pd.read_csv(CSV_PATH)

# 4. 예측에 사용할 컬럼 정의
required_features = [
    'duration',
    'total_fiat',
    'min_biat',
    'max_fiat',
    'max_biat',
    'mean_fiat',
    'flowBytesPerSecond',
    'min_flowiat',
    'mean_flowiat'
]

# 5. 입력 데이터에서 필요한 컬럼만 추출
X = df[required_features]

# 6. 예측 수행
predictions = model.predict(X)

# 7. 예측 결과 추가
df["prediction"] = predictions  # 예: 0 = Non-VPN, 1 = VPN

# 8. 결과 저장
df.to_csv("classified_sessions.csv", index=False)

# 9. 출력 (선택)
print(df[["duration", "prediction"]].head())
# Out:
#     duration  prediction
# 0  37.005820           0
# 1  28.001969           0
# 2  34.006204           0
# 3   0.427439           0
# 4   0.173898           0

# %%
import pandas as pd
import joblib

# 1. 모델 경로 및 데이터 경로 설정
MODEL_PATH = "xgb_model.pkl"  # 모델 경로
CSV_PATH = "non_vpn_session_features_iscx_format.csv"  # 입력 데이터 CSV 경로

# 2. 모델 로드
model = joblib.load(MODEL_PATH)

# 3. 입력 데이터 로드
df = pd.read_csv(CSV_PATH)

# 4. 예측에 사용할 컬럼 정의
required_features = [
    'duration',
    'total_fiat',
    'min_biat',
    'max_fiat',
    'max_biat',
    'mean_fiat',
    'flowBytesPerSecond',
    'min_flowiat',
    'mean_flowiat'
]

# 5. 입력 데이터에서 필요한 컬럼만 추출
X = df[required_features]

# 6. 예측 수행
predictions = model.predict(X)

# 7. 예측 결과 추가
df["prediction"] = predictions  # 예: 0 = Non-VPN, 1 = VPN

# 8. 결과 저장
df.to_csv("non_vpn_classified_sessions.csv", index=False)

# 9. 출력 (선택)
print(df[["duration", "prediction"]].head())
# Out:
#     duration  prediction
# 0   0.220817           0
# 1   0.004875           0
# 2  46.044571           0
# 3  46.031441           0
# 4  45.467138           0

# %%
import pandas as pd
import joblib

# 1. 모델 경로 및 데이터 경로 설정
MODEL_PATH = "xgb_model.pkl"  # 모델 경로
CSV_PATH = "/Users/kjy/Desktop/4-1/산수프/Capstone25SS/1_session_features_iscx_format.csv"  # 입력 데이터 CSV 경로

# 2. 모델 로드
model = joblib.load(MODEL_PATH)

# 3. 입력 데이터 로드
df = pd.read_csv(CSV_PATH)

# 4. 예측에 사용할 컬럼 정의
required_features = [
    'duration',
    'total_fiat',
    'min_biat',
    'max_fiat',
    'max_biat',
    'mean_fiat',
    'flowBytesPerSecond',
    'min_flowiat',
    'mean_flowiat'
]

# 5. 입력 데이터에서 필요한 컬럼만 추출
X = df[required_features]

# 6. 예측 수행
predictions = model.predict(X)

# 7. 예측 결과 추가
df["prediction"] = predictions  # 예: 0 = Non-VPN, 1 = VPN

# 8. 결과 저장
df.to_csv("1_classified_sessions.csv", index=False)

# 9. 출력 (선택)
print(df[["duration", "prediction"]].head())
# Out:
#      duration  prediction
# 0  299.314189           0
# 1   41.297840           0
# 2  299.314190           0
# 3   42.432059           0
# 4   84.709146           0

# %%
import pandas as pd
import joblib

# 1. 모델 경로 및 데이터 경로 설정
MODEL_PATH = "xgb_model.pkl"  # 모델 경로
CSV_PATH = "/Users/kjy/Desktop/4-1/산수프/Capstone25SS/traffic캡처/test.csv"  # 입력 데이터 CSV 경로

# 2. 모델 로드
model = joblib.load(MODEL_PATH)

# 3. 입력 데이터 로드
df = pd.read_csv(CSV_PATH)

# 4. 예측에 사용할 컬럼 정의
required_features = [
    'duration',
    'total_fiat',
    'min_biat',
    'max_fiat',
    'max_biat',
    'mean_fiat',
    'flowBytesPerSecond',
    'min_flowiat',
    'mean_flowiat'
]

# 5. 입력 데이터에서 필요한 컬럼만 추출
X = df[required_features]

# 6. 예측 수행
predictions = model.predict(X)

# 7. 예측 결과 추가
df["prediction"] = predictions  # 예: 0 = Non-VPN, 1 = VPN

# 8. 결과 저장
df.to_csv("1_classified_sessions.csv", index=False)

# 9. 출력 (선택)
print(df[["duration", "prediction"]].head())
# Out:
#      duration  prediction
# 0  118.616634           0
# 1  285.707149           0
# 2  222.278243           0
# 3  183.610960           0
# 4   55.245406           0

# %%
import pandas as pd
import joblib

# 1. 모델 경로 및 데이터 경로 설정
MODEL_PATH = "xgb_model.pkl"  # 모델 경로
CSV_PATH = "/Users/kjy/Desktop/4-1/산수프/Capstone25SS/test0522vpn.csv"  # 입력 데이터 CSV 경로

# 2. 모델 로드
model = joblib.load(MODEL_PATH)

# 3. 입력 데이터 로드
df = pd.read_csv(CSV_PATH)

# 4. 예측에 사용할 컬럼 정의
required_features = [
    'duration',
    'total_fiat',
    'min_biat',
    'max_fiat',
    'max_biat',
    'mean_fiat',
    'flowBytesPerSecond',
    'min_flowiat',
    'mean_flowiat'
]

# 5. 입력 데이터에서 필요한 컬럼만 추출
X = df[required_features]

# 6. 예측 수행
predictions = model.predict(X)

# 7. 예측 결과 추가
df["prediction"] = predictions  # 예: 0 = Non-VPN, 1 = VPN

# 8. 결과 저장
df.to_csv("testvpnclass.csv", index=False)

# 9. 출력 (선택)
print(df[["duration", "prediction"]].head())
# Out:
#      duration  prediction
# 0  299.314312           0
# 1   42.451996           0
# 2    3.224299           0
# 3   84.709161           0
# 4   90.927979           0

# %%
import joblib
import pandas as pd

# 1. 세션 피처 데이터 로드
df = pd.read_csv("/Users/kjy/Desktop/4-1/산수프/Capstone25SS/test0522vpn.csv")

# 2. 모델 로드
model = joblib.load("/Users/kjy/Desktop/4-1/산수프/Capstone25SS/test_xgb_model.pkl")

# 3. 모델이 요구하는 피처 이름 목록
required_features = [
    'duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat', 
    'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat',
    'flowPktsPerSecond', 'flowBytesPerSecond',
    'min_flowiat', 'max_flowiat', 'mean_flowiat', 'std_flowiat',
    'min_active', 'mean_active', 'max_active', 'std_active',
    'min_idle', 'mean_idle', 'max_idle', 'std_idle',
    'std_fiat', 'std_biat'
]

# 4. 누락된 컬럼은 0으로 채우기
for col in required_features:
    if col not in df.columns:
        df[col] = 0

# 5. 피처만 추출
X = df[required_features]

# 6. 예측
predictions = model.predict(X)

# 7. 결과 추가
df["prediction"] = predictions

# 8. 일부 결과 출력
print("🎯 예측 결과 미리보기:")
print(df[["duration", "flowBytesPerSecond", "prediction"]].head())

# 9. 전체 결과 저장
df.to_csv("test_predicted_sessions.csv", index=False)
# Out:
# 🎯 예측 결과 미리보기:
#      duration  flowBytesPerSecond  prediction
# 0  299.314312       158528.473457           1
# 1   42.451996         2650.546759           1
# 2    3.224299         1297.026036           1
# 3   84.709161          260.290619           1
# 4   90.927979          743.390547           1

# %%
import joblib
import pandas as pd

# 1. 세션 피처 데이터 로드
df = pd.read_csv("/Users/kjy/Desktop/4-1/산수프/Capstone25SS/traffic캡처/nonvpn캡처/non_vpn_session_features_iscx_format.csv")

# 2. 모델 로드
model = joblib.load("/Users/kjy/Desktop/4-1/산수프/Capstone25SS/test_xgb_model.pkl")

# 3. 모델이 요구하는 피처 이름 목록
required_features = [
    'duration', 'total_fiat', 'total_biat', 'min_fiat', 'min_biat', 
    'max_fiat', 'max_biat', 'mean_fiat', 'mean_biat',
    'flowPktsPerSecond', 'flowBytesPerSecond',
    'min_flowiat', 'max_flowiat', 'mean_flowiat', 'std_flowiat',
    'min_active', 'mean_active', 'max_active', 'std_active',
    'min_idle', 'mean_idle', 'max_idle', 'std_idle',
    'std_fiat', 'std_biat'
]

# 4. 누락된 컬럼은 0으로 채우기
for col in required_features:
    if col not in df.columns:
        df[col] = 0

# 5. 피처만 추출
X = df[required_features]

# 6. 예측
predictions = model.predict(X)

# 7. 결과 추가
df["prediction"] = predictions

# 8. 일부 결과 출력
print("🎯 예측 결과 미리보기:")
print(df[["duration", "flowBytesPerSecond", "prediction"]].head())

# 9. 전체 결과 저장
df.to_csv("test_nonvpn_predicted_sessions.csv", index=False)
# Out:
# 🎯 예측 결과 미리보기:
#     duration  flowBytesPerSecond  prediction
# 0   0.220817         1281.603707           1
# 1   0.004875        46974.891965           1
# 2  46.044571           15.115789           1
# 3  46.031441           15.467689           1
# 4  45.467138            6.950075           1
